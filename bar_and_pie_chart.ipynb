# %% [markdown]
# <a href="https://colab.research.google.com/github/01fe21bec088/Python_for_ML/blob/main/bar_and_pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["karnataka","AP","TN","TG"])
y=np.array([65,68,89,86])

plt.bar(x,y)
plt.show()

plt.pie(y)
plt.show()
