# %% [markdown]
# <a href="https://colab.research.google.com/github/01fe21bec088/Python_for_ML/blob/main/histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #code_academy website for more information on types of histograms

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(5, 1, 100000)

plt.hist(x,100)
plt.show()

x=np.random.normal(5, 1, 100)

plt.hist(x,10)
plt.show()
